# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import linregress

# Load data
data = pd.read_csv('epa-sea-level.csv')

# Scatter plot of Year vs CSIRO Adjusted Sea Level
plt.figure(figsize=(10, 6))
plt.scatter(data['Year'], data['CSIRO Adjusted Sea Level'], s=10, label='Data')

# Line of best fit for all data, extended to 2050
slope_all, intercept_all, _, _, _ = linregress(data['Year'], data['CSIRO Adjusted Sea Level'])
years_extended_all = range(data['Year'].min(), 2051)
line_all_extended = [intercept_all + slope_all * year for year in years_extended_all]
plt.plot(years_extended_all, line_all_extended, 'r--', label='Projection to 2050 (All Data)')

# Line of best fit for data from 2000 onward, extended to 2050
data_2000 = data[data['Year'] >= 2000]
slope_2000, intercept_2000, _, _, _ = linregress(data_2000['Year'], data_2000['CSIRO Adjusted Sea Level'])
years_extended_2000 = range(2000, 2051)
line_2000_extended = [intercept_2000 + slope_2000 * year for year in years_extended_2000]
plt.plot(years_extended_2000, line_2000_extended, 'g-', label='Projection to 2050 (2000 onwards)')

# Labels and title
plt.xlabel('Year')
plt.ylabel('Sea Level (inches)')
plt.title('Rise in Sea Level')
plt.legend()
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
